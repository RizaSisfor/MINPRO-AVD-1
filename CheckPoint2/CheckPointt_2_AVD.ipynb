# %% [markdown]
# # Check Point 2

# %%
import pandas as pd

# %% [markdown]
# # Data Understanding

# %% [markdown]
# Sumber dataset: https://www.google.com/url?q=https%3A%2F%2Fwww.google.com%2Furl%3Fq%3Dhttps%253A%252F%252Fwww.kaggle.com%252Fdatasets%252Fkashishparmar02%252Fsocial-media-sentiments-analysis-dataset

# %%
df = pd.read_csv("/content/sentimentdataset.csv")

# %% [markdown]
# 1. Cek Jumlah Baris Kolom

# %%
print(f"Dataset memiliki {df.shape[0]} baris dan {df.shape[1]} kolom.\n")
# Out:
# Dataset memiliki 732 baris dan 15 kolom.

# %% [markdown]
# 2. Cek tipe data setiap kolom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  732 non-null    int64
#  1   Unnamed: 0    732 non-null    int64
#  2   Text          732 non-null    object
#  3   Sentiment     732 non-null    object
#  4   Timestamp     732 non-null    object
#  5   User          732 non-null    object
#  6   Platform      732 non-null    object
#  7   Hashtags      732 non-null    object
#  8   Retweets      732 non-null    float64
#  9   Likes         732 non-null    float64
#  10  Country       732 non-null    object
#  11  Year          732 non-null    int64
#  12  Month         732 non-null    int64
#  13  Day           732 non-null    int64
#  14  Hour          732 non-null    int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 85.9+ KB

# %% [markdown]
# 3. Tampilkan 5 data pertama dan terakhir untuk melihat isi dataset (jika baris banyak)

# %%
df
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               0           0
# 1               1           1
# 2               2           2
# 3               3           3
# 4               4           4
# ..            ...         ...
# 727           728         732
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text    Sentiment  \
# 0     Enjoying a beautiful day at the park!        ...   Positive
# 1     Traffic was terrible this morning.           ...   Negative
# 2     Just finished an amazing workout! 💪          ...   Positive
# 3     Excited about the upcoming weekend getaway!  ...   Positive
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# ..                                                 ...          ...
# 727  Collaborating on a science project that receiv...       Happy
# ...

# %% [markdown]
# 4. Statistik Descriptif

# %%
df.describe()
# Out:
#        Unnamed: 0.1  Unnamed: 0    Retweets       Likes         Year  \
# count    732.000000  732.000000  732.000000  732.000000   732.000000
# mean     366.464481  369.740437   21.508197   42.901639  2020.471311
# std      211.513936  212.428936    7.061286   14.089848     2.802285
# min        0.000000    0.000000    5.000000   10.000000  2010.000000
# 25%      183.750000  185.750000   17.750000   34.750000  2019.000000
# 50%      366.500000  370.500000   22.000000   43.000000  2021.000000
# 75%      549.250000  553.250000   25.000000   50.000000  2023.000000
# max      732.000000  736.000000   40.000000   80.000000  2023.000000
#
#             Month         Day        Hour
# count  732.000000  732.000000  732.000000
# mean     6.122951   15.497268   15.521858
# std      3.411763    8.474553    4.113414
# min      1.000000    1.000000    0.000000
# 25%      3.000000    9.000000   13.000000
# 50%      6.000000   15.000000   16.000000
# 75%      9.000000   22.000000   19.000000
# ...

# %% [markdown]
# 5. Analisis Korelasi

# %%
corr_matrix = df[["Retweets", "Likes"]].corr()

# %%
print("\nMatriks Korelasi:")
print(corr_matrix)
# Out:
# Matriks Korelasi:
#           Retweets     Likes
# Retweets  1.000000  0.998482
# Likes     0.998482  1.000000

# %% [markdown]
# # Data Preparation

# %% [markdown]
# **A. Pengecekan terhadap Data**

# %% [markdown]
# 1. Nilai yang hilang (Missing Values)

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# Unnamed: 0.1    0.0
# Unnamed: 0      0.0
# Text            0.0
# Sentiment       0.0
# Timestamp       0.0
# User            0.0
# Platform        0.0
# Hashtags        0.0
# Retweets        0.0
# Likes           0.0
# Country         0.0
# Year            0.0
# Month           0.0
# Day             0.0
# Hour            0.0
# dtype: float64

# %% [markdown]
# 2. Duplicated Values

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, Text, Sentiment, Timestamp, User, Platform, Hashtags, Retweets, Likes, Country, Year, Month, Day, Hour]
# Index: []

# %% [markdown]
# 3. Outliers

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom         Persentase Outliers
# Unnamed: 0.1             0.000000
# Unnamed: 0               0.000000
# Retweets                 2.459016
# Likes                    2.459016
# Year                     1.502732
# Month                    0.000000
# Day                      0.000000
# Hour                     0.683060

# %%
df
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               0           0
# 1               1           1
# 2               2           2
# 3               3           3
# 4               4           4
# ..            ...         ...
# 727           728         732
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text    Sentiment  \
# 0     Enjoying a beautiful day at the park!        ...   Positive
# 1     Traffic was terrible this morning.           ...   Negative
# 2     Just finished an amazing workout! 💪          ...   Positive
# 3     Excited about the upcoming weekend getaway!  ...   Positive
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# ..                                                 ...          ...
# 727  Collaborating on a science project that receiv...       Happy
# ...

# %% [markdown]
# 4. Incosistent Value

# %% [markdown]
# Berdasarkan dataset yang saya teliti, saya tidak ada nilai yang tidak konsisten

# %% [markdown]
# **B. Penanganan terhadap Data**

# %% [markdown]
# * Retweets (Imputasi)

# %%
df['Retweets'].dropna().describe()
# Out:
# count    732.000000
# mean      21.508197
# std        7.061286
# min        5.000000
# 25%       17.750000
# 50%       22.000000
# 75%       25.000000
# max       40.000000
# Name: Retweets, dtype: float64

# %%
df['Retweets'] = df['Retweets'].fillna(df['Retweets'].dropna().mean())

# %% [markdown]
# * Likes (Imputasi)

# %%
df['Likes'].dropna().describe()
# Out:
# count    732.000000
# mean      42.901639
# std       14.089848
# min       10.000000
# 25%       34.750000
# 50%       43.000000
# 75%       50.000000
# max       80.000000
# Name: Likes, dtype: float64

# %%
df['Likes'] = df['Likes'].fillna(df['Likes'].dropna().mean())

# %% [markdown]
# 2. Duplicated Values (Dihapus semua duplikasi)

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               0           0
# 1               1           1
# 2               2           2
# 3               3           3
# 4               4           4
# ..            ...         ...
# 727           728         732
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text    Sentiment  \
# 0     Enjoying a beautiful day at the park!        ...   Positive
# 1     Traffic was terrible this morning.           ...   Negative
# 2     Just finished an amazing workout! 💪          ...   Positive
# 3     Excited about the upcoming weekend getaway!  ...   Positive
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# ..                                                 ...          ...
# 727  Collaborating on a science project that receiv...       Happy
# ...

# %% [markdown]
# 3. Outliers (Melakukan Imputasi)

# %%
columns_to_impute = ["Retweets", "Likes"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Menggunakan .loc[] agar tidak muncul SettingWithCopyWarning
    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %% [markdown]
# Melakukan pengecekan ulang

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom         Persentase Outliers
# Unnamed: 0.1             0.000000
# Unnamed: 0               0.000000
# Retweets                 0.000000
# Likes                    0.000000
# Year                     1.502732
# Month                    0.000000
# Day                      0.000000
# Hour                     0.683060

# %%
df
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               0           0
# 1               1           1
# 2               2           2
# 3               3           3
# 4               4           4
# ..            ...         ...
# 727           728         732
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text    Sentiment  \
# 0     Enjoying a beautiful day at the park!        ...   Positive
# 1     Traffic was terrible this morning.           ...   Negative
# 2     Just finished an amazing workout! 💪          ...   Positive
# 3     Excited about the upcoming weekend getaway!  ...   Positive
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# ..                                                 ...          ...
# 727  Collaborating on a science project that receiv...       Happy
# ...

# %% [markdown]
# 4. Incosistent Value

# %% [markdown]
# Menurut Saya, dataset yang saya teliti tidak ada nilai yang tidak konsisten

# %% [markdown]
# # konstruksi data (Construct Data) (penambahan kolom)

# %% [markdown]
# Penambahan kolom: Kategori Retweets

# %%
df_cleaned = df.copy()

# %%
df_cleaned["Retweets"] = pd.to_numeric(df_cleaned["Retweets"], errors="coerce")

# %%
def kategori_Retweets(Retweets):
  if Retweets <= 10:
      return "Low"
  elif 11 <= Retweets <= Retweets <= 500:
      return "Medium"
  elif 101 <= Retweets <= 500:
      return "High"
  else:
      return "Viral"

# %%
df_cleaned["kategori_Retweets"] = df_cleaned["Retweets"].apply(kategori_Retweets)

# %%
print(df_cleaned[["Retweets", "kategori_Retweets"]])
# Out:
#      Retweets kategori_Retweets
# 0      15.000            Medium
# 1       6.875               Low
# 2      20.000            Medium
# 3       8.000               Low
# 4      12.000            Medium
# ..        ...               ...
# 727    20.000            Medium
# 728    25.000            Medium
# 729    22.000            Medium
# 730    21.000            Medium
# 731    24.000            Medium
#
# [732 rows x 2 columns]

# %% [markdown]
# Penambahan Kolom: Kategori Likes

# %%
if "Likes" in df_cleaned.columns:
    df_cleaned["Likes_disesuaikan"] = df_cleaned["Likes"] * 10

print(df_cleaned[["Likes", "Likes_disesuaikan"]])
# Out:
#       Likes  Likes_disesuaikan
# 0    30.000             300.00
# 1    11.875             118.75
# 2    40.000             400.00
# 3    15.000             150.00
# 4    25.000             250.00
# ..      ...                ...
# 727  39.000             390.00
# 728  48.000             480.00
# 729  42.000             420.00
# 730  43.000             430.00
# 731  47.000             470.00
#
# [732 rows x 2 columns]

# %% [markdown]
# # Reduksi data (Data Reduction)

# %%
# Daftar kolom yang akan dihapus (sesuaikan dengan dataset)
columns_to_drop = ["Unnamed: 0", "Timestamp", "User", "Platform"]

# Hapus kolom yang tidak relevan
df_cleaned = df_cleaned.drop(columns=columns_to_drop, errors='ignore')

# Tampilkan kolom yang tersisa setelah reduksi
print(df_cleaned.columns)
# Out:
# Index(['Unnamed: 0.1', 'Text', 'Sentiment', 'Hashtags', 'Retweets', 'Likes',
#        'Country', 'Year', 'Month', 'Day', 'Hour', 'kategori_Retweets',
#        'Likes_disesuaikan'],
#       dtype='object')

# %%
df
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               0           0
# 1               1           1
# 2               2           2
# 3               3           3
# 4               4           4
# ..            ...         ...
# 727           728         732
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text    Sentiment  \
# 0     Enjoying a beautiful day at the park!        ...   Positive
# 1     Traffic was terrible this morning.           ...   Negative
# 2     Just finished an amazing workout! 💪          ...   Positive
# 3     Excited about the upcoming weekend getaway!  ...   Positive
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# ..                                                 ...          ...
# 727  Collaborating on a science project that receiv...       Happy
# ...
